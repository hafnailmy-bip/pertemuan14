# %% [markdown]
# <a href="https://colab.research.google.com/github/hafnailmy-bip/pertemuan14/blob/main/PCD_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# KLASIFIKASI CITRA DENGAN CNN DAN TRANSFER LEARNING
# ============================================================
# Dataset  : CIFAR-10
# Metode   :
# 1. CNN From Scratch
# 2. Transfer Learning (VGG16)
# 3. Data Augmentation
# 4. Fine-Tuning
# 5. Evaluasi Lengkap
# ============================================================

# =========================
# IMPORT LIBRARY
# =========================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc
)

from sklearn.preprocessing import label_binarize
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')

# ============================================================
# LOAD DATASET CIFAR-10
# ============================================================
print("LOADING CIFAR-10 DATASET...")

(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)

# ============================================================
# NORMALISASI DATA
# ============================================================
X_train = X_train.astype('float32') / 255.0
X_test  = X_test.astype('float32') / 255.0

# One-hot encoding
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat  = keras.utils.to_categorical(y_test, 10)

# ============================================================
# VISUALISASI DATASET
# ============================================================
plt.figure(figsize=(10,10))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(X_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')

plt.suptitle("Sample CIFAR-10 Images")
plt.tight_layout()
plt.show()

# ============================================================
# DATA AUGMENTATION
# ============================================================
print("\nMEMBUAT DATA AUGMENTATION...")

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

datagen.fit(X_train)

# ============================================================
# VISUALISASI AUGMENTASI
# ============================================================
plt.figure(figsize=(12,6))

sample = X_train[0]

for i in range(10):

    augmented = datagen.random_transform(sample)

    plt.subplot(2,5,i+1)
    plt.imshow(augmented)
    plt.axis('off')

plt.suptitle("Data Augmentation Examples")
plt.tight_layout()
plt.show()

# ============================================================
# CNN FROM SCRATCH
# ============================================================
print("\nMEMBANGUN CNN FROM SCRATCH...")

cnn_model = Sequential([

    # Input Layer
    layers.Input(shape=(32,32,3)),

    # Convolution Block 1
    layers.Conv2D(
        32,
        (3,3),
        activation='relu',
        padding='same'
    ),

    layers.BatchNormalization(),

    layers.MaxPooling2D((2,2)),

    layers.Dropout(0.25),

    # Convolution Block 2
    layers.Conv2D(
        64,
        (3,3),
        activation='relu',
        padding='same'
    ),

    layers.BatchNormalization(),

    layers.MaxPooling2D((2,2)),

    layers.Dropout(0.25),

    # Convolution Block 3
    layers.Conv2D(
        128,
        (3,3),
        activation='relu',
        padding='same'
    ),

    layers.BatchNormalization(),

    layers.MaxPooling2D((2,2)),

    layers.Dropout(0.25),

    # Fully Connected
    layers.Flatten(),

    layers.Dense(256, activation='relu'),

    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')

])

# ============================================================
# BUILD MODEL
# ============================================================
cnn_model.build((None, 32, 32, 3))

# ============================================================
# COMPILE MODEL
# ============================================================
cnn_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# MODEL SUMMARY
# ============================================================
cnn_model.summary()

# ============================================================
# CALLBACKS
# ============================================================
callbacks = [

    keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=5,
        restore_best_weights=True
    ),

    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3
    )

]

# ============================================================
# TRAINING CNN
# ============================================================
print("\nTRAINING CNN FROM SCRATCH...")

history_cnn = cnn_model.fit(

    datagen.flow(X_train, y_train_cat, batch_size=64),

    epochs=20,

    validation_data=(X_test, y_test_cat),

    callbacks=callbacks,

    verbose=1

)

# ============================================================
# EVALUASI CNN
# ============================================================
cnn_loss, cnn_acc = cnn_model.evaluate(X_test, y_test_cat)

print("\nCNN TEST ACCURACY :", cnn_acc)

# ============================================================
# PLOT LEARNING CURVE
# ============================================================
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,5))

# Accuracy
ax1.plot(history_cnn.history['accuracy'], label='Train Accuracy')
ax1.plot(history_cnn.history['val_accuracy'], label='Validation Accuracy')

ax1.set_title('CNN Accuracy')
ax1.legend()
ax1.grid(True)

# Loss
ax2.plot(history_cnn.history['loss'], label='Train Loss')
ax2.plot(history_cnn.history['val_loss'], label='Validation Loss')

ax2.set_title('CNN Loss')
ax2.legend()
ax2.grid(True)

plt.show()

# ============================================================
# PREDIKSI
# ============================================================
y_pred = cnn_model.predict(X_test)

y_pred_classes = np.argmax(y_pred, axis=1)

y_true = y_test.flatten()

# ============================================================
# CONFUSION MATRIX
# ============================================================
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10,8))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ============================================================
# CLASSIFICATION REPORT
# ============================================================
print("\nCLASSIFICATION REPORT\n")

print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_names
))

# ============================================================
# ROC CURVE
# ============================================================
print("\nMEMBUAT ROC CURVE...")

y_test_bin = label_binarize(y_true, classes=range(10))

plt.figure(figsize=(10,8))

for i in range(10):

    fpr, tpr, _ = roc_curve(
        y_test_bin[:, i],
        y_pred[:, i]
    )

    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        label=f'{class_names[i]} (AUC={roc_auc:.2f})'
    )

plt.plot([0,1], [0,1], 'k--')

plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# ============================================================
# VISUALISASI PREDIKSI
# ============================================================
plt.figure(figsize=(12,12))

for i in range(25):

    plt.subplot(5,5,i+1)

    plt.imshow(X_test[i])

    pred = y_pred_classes[i]
    true = y_true[i]

    color = 'green' if pred == true else 'red'

    plt.title(
        f"T:{class_names[true]}\nP:{class_names[pred]}",
        color=color,
        fontsize=8
    )

    plt.axis('off')

plt.suptitle("Prediction Results")
plt.tight_layout()
plt.show()

# ============================================================
# FEATURE MAP VISUALIZATION
# ============================================================
print("\nVISUALISASI FEATURE MAP...")

# PERBAIKAN ERROR DI SINI
sample_image = X_test[0:1]

# Pastikan model sudah dipanggil
_ = cnn_model(sample_image)

layer_outputs = [layer.output for layer in cnn_model.layers[:4]]

activation_model = keras.Model(
    inputs=cnn_model.inputs,
    outputs=layer_outputs
)

activations = activation_model.predict(sample_image)

first_layer_activation = activations[0]

plt.figure(figsize=(12,8))

for i in range(16):

    plt.subplot(4,4,i+1)

    plt.imshow(
        first_layer_activation[0,:,:,i],
        cmap='viridis'
    )

    plt.axis('off')

plt.suptitle("Feature Maps")
plt.tight_layout()
plt.show()

# ============================================================
# TRANSFER LEARNING - VGG16
# ============================================================
print("\nTRANSFER LEARNING DENGAN VGG16...")

base_model = keras.applications.VGG16(

    weights='imagenet',

    include_top=False,

    input_shape=(32,32,3)

)

# Freeze base model
base_model.trainable = False

# ============================================================
# BUILD TRANSFER MODEL
# ============================================================
transfer_model = Sequential([

    layers.Input(shape=(32,32,3)),

    base_model,

    layers.Flatten(),

    layers.Dense(256, activation='relu'),

    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')

])

# ============================================================
# BUILD MODEL
# ============================================================
transfer_model.build((None, 32, 32, 3))

# ============================================================
# COMPILE MODEL
# ============================================================
transfer_model.compile(

    optimizer='adam',

    loss='categorical_crossentropy',

    metrics=['accuracy']

)

transfer_model.summary()

# ============================================================
# TRAIN TRANSFER MODEL
# ============================================================
print("\nTRAINING TRANSFER LEARNING MODEL...")

history_transfer = transfer_model.fit(

    datagen.flow(X_train, y_train_cat, batch_size=64),

    epochs=10,

    validation_data=(X_test, y_test_cat),

    verbose=1

)

# ============================================================
# EVALUASI TRANSFER LEARNING
# ============================================================
transfer_loss, transfer_acc = transfer_model.evaluate(
    X_test,
    y_test_cat
)

print("\nTRANSFER LEARNING ACCURACY :", transfer_acc)

# ============================================================
# FINE TUNING
# ============================================================
print("\nFINE TUNING MODEL...")

base_model.trainable = True

for layer in base_model.layers[:-4]:
    layer.trainable = False

transfer_model.compile(

    optimizer=keras.optimizers.Adam(1e-5),

    loss='categorical_crossentropy',

    metrics=['accuracy']

)

history_fine = transfer_model.fit(

    datagen.flow(X_train, y_train_cat, batch_size=64),

    epochs=5,

    validation_data=(X_test, y_test_cat),

    verbose=1

)

# ============================================================
# FINAL EVALUATION
# ============================================================
fine_loss, fine_acc = transfer_model.evaluate(
    X_test,
    y_test_cat
)

print("\nFINAL FINE-TUNING ACCURACY :", fine_acc)

# ============================================================
# PCA VISUALIZATION
# ============================================================
print("\nPCA VISUALIZATION...")

features = cnn_model.predict(X_test[:1000])

pca = PCA(n_components=2)

pca_result = pca.fit_transform(features)

plt.figure(figsize=(10,8))

scatter = plt.scatter(
    pca_result[:,0],
    pca_result[:,1],
    c=y_true[:1000],
    cmap='tab10'
)

plt.colorbar(scatter)
plt.title("PCA Feature Visualization")
plt.show()

# ============================================================
# t-SNE VISUALIZATION
# ============================================================
print("\nt-SNE VISUALIZATION...")

tsne = TSNE(
    n_components=2,
    random_state=42
)

tsne_result = tsne.fit_transform(features)

plt.figure(figsize=(10,8))

scatter = plt.scatter(
    tsne_result[:,0],
    tsne_result[:,1],
    c=y_true[:1000],
    cmap='tab10'
)

plt.colorbar(scatter)
plt.title("t-SNE Feature Visualization")
plt.show()

# ============================================================
# PERBANDINGAN MODEL
# ============================================================
models_name = ['CNN', 'Transfer Learning', 'Fine-Tuning']

accuracy = [
    cnn_acc,
    transfer_acc,
    fine_acc
]

plt.figure(figsize=(8,5))

bars = plt.bar(models_name, accuracy)

for bar, acc in zip(bars, accuracy):

    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 0.01,
        f'{acc:.3f}',
        ha='center'
    )

plt.ylim(0,1)

plt.ylabel("Accuracy")

plt.title("Model Comparison")

plt.show()

# ============================================================
# KESIMPULAN
# ============================================================
print("\nKESIMPULAN")
print("="*50)

print(f"""
1. CNN From Scratch Accuracy :
   {cnn_acc:.4f}

2. Transfer Learning Accuracy :
   {transfer_acc:.4f}

3. Fine-Tuning Accuracy :
   {fine_acc:.4f}

4. Transfer Learning biasanya memberikan
   hasil lebih baik dan training lebih cepat.

5. Data augmentation membantu mengurangi
   overfitting dan meningkatkan generalisasi model.

6. Fine-tuning dapat meningkatkan performa
   model dibanding feature extraction biasa.
""")

print("\nPROGRAM SELESAI")
# Out:
# LOADING CIFAR-10 DATASET...
# Training Shape : (50000, 32, 32, 3)
# Testing Shape  : (10000, 32, 32, 3)
# MEMBUAT DATA AUGMENTATION...
# MEMBANGUN CNN FROM SCRATCH...
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 621,258 (2.37 MB)
#  Trainable params: 620,810 (2.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# TRAINING CNN FROM SCRATCH...
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 52ms/step - accuracy: 0.3025 - loss: 1.9174 - val_accuracy: 0.3713 - val_loss: 1.8286 - learning_rate: 0.0010
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.3893 - loss: 1.6731 - val_accuracy: 0.3620 - val_loss: 1.9404 - learning_rate: 0.0010
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.4344 - loss: 1.5584 - val_accuracy: 0.5024 - val_loss: 1.3460 - learning_rate: 0.0010
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.4677 - loss: 1.4845 - val_accuracy: 0.5634 - val_loss: 1.2079 - learning_rate: 0.0010
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.4943 - loss: 1.4185 - val_accuracy: 0.5773 - val_loss: 1.2138 - learning_rate: 0.0010
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.5112 - loss: 1.3715 - val_accuracy: 0.5152 - val_loss: 1.4446 - learning_rate: 0.0010
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.5293 - loss: 1.3293 - val_accuracy: 0.6408 - val_loss: 1.0157 - learning_rate: 0.0010
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.5458 - loss: 1.2918 - val_accuracy: 0.5568 - val_loss: 1.4595 - learning_rate: 0.0010
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.5539 - loss: 1.2659 - val_accuracy: 0.5900 - val_loss: 1.2356 - learning_rate: 0.0010
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.5649 - loss: 1.2375 - val_accuracy: 0.6496 - val_loss: 1.0230 - learning_rate: 0.0010
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.5950 - loss: 1.1620 - val_accuracy: 0.6565 - val_loss: 1.0235 - learning_rate: 5.0000e-04
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.5987 - loss: 1.1452 - val_accuracy: 0.6936 - val_loss: 0.8867 - learning_rate: 5.0000e-04
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6093 - loss: 1.1202 - val_accuracy: 0.6604 - val_loss: 1.0377 - learning_rate: 5.0000e-04
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.6117 - loss: 1.1093 - val_accuracy: 0.7077 - val_loss: 0.8490 - learning_rate: 5.0000e-04
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6170 - loss: 1.0950 - val_accuracy: 0.6934 - val_loss: 0.8948 - learning_rate: 5.0000e-04
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6226 - loss: 1.0823 - val_accuracy: 0.7169 - val_loss: 0.8234 - learning_rate: 5.0000e-04
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6275 - loss: 1.0699 - val_accuracy: 0.6304 - val_loss: 1.1462 - learning_rate: 5.0000e-04
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6318 - loss: 1.0564 - val_accuracy: 0.6814 - val_loss: 0.9395 - learning_rate: 5.0000e-04
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.6349 - loss: 1.0478 - val_accuracy: 0.6561 - val_loss: 1.0228 - learning_rate: 5.0000e-04
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6474 - loss: 1.0156 - val_accuracy: 0.7107 - val_loss: 0.8409 - learning_rate: 2.5000e-04
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7169 - loss: 0.8234
#
# CNN TEST ACCURACY : 0.7168999910354614
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#     airplane       0.80      0.75      0.77      1000
#   automobile       0.83      0.92      0.87      1000
#         bird       0.73      0.45      0.56      1000
#          cat       0.66      0.38      0.48      1000
#         deer       0.68      0.60      0.64      1000
#          dog       0.69      0.60      0.64      1000
#         frog       0.52      0.93      0.66      1000
#        horse       0.73      0.82      0.77      1000
#         ship       0.83      0.89      0.86      1000
#        truck       0.81      0.84      0.83      1000
#
#     accuracy                           0.72     10000
#    macro avg       0.73      0.72      0.71     10000
# weighted avg       0.73      0.72      0.71     10000
#
#
# MEMBUAT ROC CURVE...
# VISUALISASI FEATURE MAP...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# TRANSFER LEARNING DENGAN VGG16...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 1, 1, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,586 (56.64 MB)
#  Trainable params: 133,898 (523.04 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# TRAINING TRANSFER LEARNING MODEL...
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 57ms/step - accuracy: 0.3938 - loss: 1.7126 - val_accuracy: 0.5105 - val_loss: 1.4066
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.4539 - loss: 1.5435 - val_accuracy: 0.5358 - val_loss: 1.3202
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.4712 - loss: 1.4972 - val_accuracy: 0.5388 - val_loss: 1.3024
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.4808 - loss: 1.4715 - val_accuracy: 0.5504 - val_loss: 1.2657
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.4850 - loss: 1.4597 - val_accuracy: 0.5458 - val_loss: 1.2899
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.4892 - loss: 1.4463 - val_accuracy: 0.5619 - val_loss: 1.2580
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.4939 - loss: 1.4314 - val_accuracy: 0.5510 - val_loss: 1.2524
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.4990 - loss: 1.4279 - val_accuracy: 0.5506 - val_loss: 1.2611
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.5037 - loss: 1.4208 - val_accuracy: 0.5647 - val_loss: 1.2389
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.5020 - loss: 1.4120 - val_accuracy: 0.5629 - val_loss: 1.2423
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5629 - loss: 1.2423
#
# TRANSFER LEARNING ACCURACY : 0.5629000067710876
#
# FINE TUNING MODEL...
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 60ms/step - accuracy: 0.5394 - loss: 1.3192 - val_accuracy: 0.6228 - val_loss: 1.0754
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.5697 - loss: 1.2252 - val_accuracy: 0.6374 - val_loss: 1.0349
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.5894 - loss: 1.1721 - val_accuracy: 0.6457 - val_loss: 1.0004
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6051 - loss: 1.1309 - val_accuracy: 0.6550 - val_loss: 0.9851
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.6121 - loss: 1.1091 - val_accuracy: 0.6692 - val_loss: 0.9441
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6692 - loss: 0.9441
#
# FINAL FINE-TUNING ACCURACY : 0.6692000031471252
#
# PCA VISUALIZATION...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# t-SNE VISUALIZATION...
# KESIMPULAN
# ==================================================
#
# 1. CNN From Scratch Accuracy :
#    0.7169
#
# 2. Transfer Learning Accuracy :
#    0.5629
#
# 3. Fine-Tuning Accuracy :
#    0.6692
#
# 4. Transfer Learning biasanya memberikan
#    hasil lebih baik dan training lebih cepat.
#
# 5. Data augmentation membantu mengurangi
#    overfitting dan meningkatkan generalisasi model.
#
# 6. Fine-tuning dapat meningkatkan performa
#    model dibanding feature extraction biasa.
#
#
# PROGRAM SELESAI
